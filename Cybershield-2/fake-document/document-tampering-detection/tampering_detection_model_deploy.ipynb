# %% [markdown]
# # Deploy the model to SageMaker Inference

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.38-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.38 (from boto3)
#   Downloading botocore-1.37.38-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from botocore<1.38.0,>=1.37.38->boto3) (2.9.0.post0)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.38.0,>=1.37.38->boto3)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#      ---------------------------------------- 50.1/50.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.38->boto3) (1.16.0)
# Downloading boto3-1.37.38-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.9 kB ? eta -:--:--
#    ----------------------------------- ---- 122.9/139.9 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 139.9/139.9 kB 2.1 MB/s eta 0:00:00
# Downloading botocore-1.37.38-py3-none-any.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.5 MB 17.1 MB/s eta 0:00:01
#    - -------------------------------------- 0.5/13.5 MB 7.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/13.5 MB 6.8 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/13.5 MB 6.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/13.5 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.5/13.5 MB 5.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.9/13.5 MB 5.5 MB/s eta 0:00:03
#    ------ --------------------------------- 2.2/13.5 MB 5.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/13.5 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.7/13.5 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.5 MB 5.4 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/13.5 MB 5.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.3/13.5 MB 5.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.5/13.5 MB 5.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.6/13.5 MB 5.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/13.5 MB 5.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.0/13.5 MB 5.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.0/13.5 MB 5.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.0/13.5 MB 5.1 MB/s eta 0:00:02
#    ------------- -------------------------- 4.5/13.5 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/13.5 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.8/13.5 MB 4.7 MB/s eta 0:00:02
#    -------------- ------------------------- 5.0/13.5 MB 4.6 MB/s eta 0:00:02
#    --------------- ------------------------ 5.2/13.5 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.4/13.5 MB 4.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.7/13.5 MB 4.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.8/13.5 MB 4.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.9/13.5 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 6.1/13.5 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 6.3/13.5 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 6.5/13.5 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 6.7/13.5 MB 4.4 MB/s eta 0:00:02
#    -------------------- ------------------- 6.9/13.5 MB 4.4 MB/s eta 0:00:02
#    -------------------- ------------------- 7.0/13.5 MB 4.4 MB/s eta 0:00:02
#    --------------------- ------------------ 7.3/13.5 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.4/13.5 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.7/13.5 MB 4.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.8/13.5 MB 4.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.0/13.5 MB 4.3 MB/s eta 0:00:02
#    ------------------------ --------------- 8.2/13.5 MB 4.4 MB/s eta 0:00:02
#    ------------------------- -------------- 8.5/13.5 MB 4.3 MB/s eta 0:00:02
#    -------------------------- ------------- 8.8/13.5 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 9.1/13.5 MB 4.4 MB/s eta 0:00:02
#    --------------------------- ------------ 9.4/13.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.7/13.5 MB 4.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.8/13.5 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.1/13.5 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 10.2/13.5 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 10.4/13.5 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 10.6/13.5 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.5 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.9/13.5 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 11.2/13.5 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 11.4/13.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.5/13.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.6/13.5 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.5 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.9/13.5 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.1/13.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.3/13.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.5/13.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.5 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 13.1/13.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 3.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.8 kB ? eta -:--:--
#    -------------------------------------- - 81.9/84.8 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 84.8/84.8 kB 1.2 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#    ---------------------------------------- 144.2/144.2 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.1
#     Uninstalling urllib3-2.2.1:
#       Successfully uninstalled urllib3-2.2.1
# Successfully installed boto3-1.37.38 botocore-1.37.38 jmespath-1.0.1 s3transfer-0.11.5 urllib3-1.26.20
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.29.2 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.15.1 which is incompatible.

# %%
# !pip install sagemaker
# Out:
# Collecting sagemaker
#   Downloading sagemaker-2.243.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: attrs<24,>=23.1.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (23.1.0)
# Requirement already satisfied: boto3<2.0,>=1.35.75 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (1.37.38)
# Collecting cloudpickle>=2.2.1 (from sagemaker)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting docker (from sagemaker)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fastapi in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (0.124.4)
# Requirement already satisfied: google-pasta in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (0.2.0)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonschema in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (4.19.2)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (1.24.3)
# Collecting omegaconf<=2.3,>=2.2 (from sagemaker)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (23.2)
# Requirement already satisfied: pandas in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (2.0.3)
# Collecting pathos (from sagemaker)
#   Downloading pathos-0.3.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (3.10.0)
# Requirement already satisfied: protobuf<6.0,>=3.12 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (3.19.6)
# Requirement already satisfied: psutil in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (5.9.8)
# Requirement already satisfied: pyyaml~=6.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (6.0.1)
# Requirement already satisfied: requests in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (2.31.0)
# Collecting sagemaker-core<2.0.0,>=1.0.17 (from sagemaker)
#   Downloading sagemaker_core-1.0.77-py3-none-any.whl.metadata (4.9 kB)
# Collecting schema (from sagemaker)
#   Downloading schema-0.7.8-py2.py3-none-any.whl.metadata (34 kB)
# Collecting smdebug-rulesconfig==1.0.1 (from sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Collecting tblib<4,>=1.7.0 (from sagemaker)
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (4.66.4)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (1.26.20)
# Requirement already satisfied: uvicorn in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker) (0.33.0)
# Requirement already satisfied: botocore<1.38.0,>=1.37.38 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from boto3<2.0,>=1.35.75->sagemaker) (1.37.38)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from boto3<2.0,>=1.35.75->sagemaker) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from boto3<2.0,>=1.35.75->sagemaker) (0.11.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker) (3.17.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<=2.3,>=2.2->sagemaker)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ---------------------------------------- 0.0/117.0 kB ? eta -:--:--
#      ------------------------------------ - 112.6/117.0 kB 3.3 MB/s eta 0:00:01
#      -------------------------------------- 117.0/117.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydantic<3.0.0,>=2.0.0 (from sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting platformdirs (from sagemaker)
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from sagemaker-core<2.0.0,>=1.0.17->sagemaker) (13.3.5)
# Collecting mock<5.0,>4.0 (from sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from jsonschema->sagemaker) (6.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from jsonschema->sagemaker) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from jsonschema->sagemaker) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from jsonschema->sagemaker) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from jsonschema->sagemaker) (0.10.6)
# Requirement already satisfied: pywin32>=304 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from docker->sagemaker) (306)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from requests->sagemaker) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from requests->sagemaker) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from requests->sagemaker) (2024.8.30)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from fastapi->sagemaker) (0.44.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from fastapi->sagemaker) (4.11.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from fastapi->sagemaker) (0.0.4)
# Requirement already satisfied: six in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from google-pasta->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from pandas->sagemaker) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from pandas->sagemaker) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from pandas->sagemaker) (2023.3)
# Collecting ppft>=1.7.7 (from pathos->sagemaker)
#   Downloading ppft-1.7.7-py3-none-any.whl.metadata (12 kB)
# Collecting dill>=0.4.0 (from pathos->sagemaker)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.6 (from pathos->sagemaker)
#   Downloading pox-0.3.6-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.18 (from pathos->sagemaker)
#   Downloading multiprocess-0.70.18-py38-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from tqdm->sagemaker) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from uvicorn->sagemaker) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from uvicorn->sagemaker) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker)
#   Downloading pydantic_core-2.27.2-cp38-cp38-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi->sagemaker)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (2.18.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi->sagemaker) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.51.0,>=0.40.0->fastapi->sagemaker) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.51.0,>=0.40.0->fastapi->sagemaker) (1.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda32\envs\iit_aiml\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.17->sagemaker) (0.1.0)
# Downloading sagemaker-2.243.2-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.6 MB 2.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.1/1.6 MB 2.9 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.6 MB 2.2 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.6 MB 2.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.4/1.6 MB 2.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.6 MB 2.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.6 MB 2.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.6 MB 2.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 2.6 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.6 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.6 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.8 MB/s eta 0:00:00
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ---------------------------------------- 0.0/79.5 kB ? eta -:--:--
#    ---------------------------------------- 79.5/79.5 kB 4.6 MB/s eta 0:00:00
# Downloading sagemaker_core-1.0.77-py3-none-any.whl (440 kB)
#    ---------------------------------------- 0.0/440.6 kB ? eta -:--:--
#    ------------------ --------------------- 204.8/440.6 kB 6.3 MB/s eta 0:00:01
#    -------------------------------- ------- 358.4/440.6 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 440.6/440.6 kB 3.4 MB/s eta 0:00:00
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.8 kB ? eta -:--:--
#    ---------------------------------------- 147.8/147.8 kB 4.4 MB/s eta 0:00:00
# Downloading pathos-0.3.4-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.3 kB ? eta -:--:--
#    ---------------------------------------- 82.3/82.3 kB 4.5 MB/s eta 0:00:00
# Downloading schema-0.7.8-py2.py3-none-any.whl (19 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.7 kB ? eta -:--:--
#    ---------------------------------------- 119.7/119.7 kB 6.8 MB/s eta 0:00:00
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading multiprocess-0.70.18-py38-none-any.whl (132 kB)
#    ---------------------------------------- 0.0/132.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/132.6 kB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 132.6/132.6 kB 3.8 MB/s eta 0:00:00
# Downloading pox-0.3.6-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.7-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.8 kB ? eta -:--:--
#    ---------------------------------------- 56.8/56.8 kB 1.5 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.7 kB ? eta -:--:--
#    ---------------- ----------------------- 174.1/431.7 kB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 358.4/431.7 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 431.7/431.7 kB 3.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp38-cp38-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.0 MB 9.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 5.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/2.0 MB 6.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 5.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/2.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.7/2.0 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#    ---------------------------------------- 45.8/45.8 kB 2.4 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144578 sha256=cda290120118b99721d5d0992b9f6cfbb7917adac3b706faf6ca4c050ebecd8c
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\b1\a3\c2\6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
# Successfully built antlr4-python3-runtime
# Installing collected packages: schema, antlr4-python3-runtime, typing-extensions, tblib, smdebug-rulesconfig, ppft, pox, platformdirs, omegaconf, mock, importlib-metadata, dill, cloudpickle, pydantic-core, multiprocess, docker, annotated-types, pydantic, pathos, sagemaker-core, sagemaker
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.10.0
#     Uninstalling platformdirs-3.10.0:
#       Successfully uninstalled platformdirs-3.10.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.14
#     Uninstalling multiprocess-0.70.14:
#       Successfully uninstalled multiprocess-0.70.14
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# Successfully installed annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 cloudpickle-3.1.2 dill-0.4.0 docker-7.1.0 importlib-metadata-6.11.0 mock-4.0.3 multiprocess-0.70.18 omegaconf-2.3.0 pathos-0.3.4 platformdirs-4.3.6 pox-0.3.6 ppft-1.7.7 pydantic-2.10.6 pydantic-core-2.27.2 sagemaker-2.243.2 sagemaker-core-1.0.77 schema-0.7.8 smdebug-rulesconfig-1.0.1 tblib-3.0.0 typing-extensions-4.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.12.0 requires dill<0.3.7,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# transformers 4.29.2 requires tokenizers!=0.11.3,<0.14,>=0.11.1, but you have tokenizers 0.15.1 which is incompatible.

# %%
import logging
import boto3
from botocore.exceptions import ClientError
import os
from sagemaker import image_uris
from sagemaker.model import Model
from datetime import datetime
import os
import numpy as np
import pandas as pd
import json

np.random.seed(2)

from PIL import Image
from pylab import *
from PIL import Image, ImageChops, ImageEnhance
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\HP\AppData\Local\sagemaker\sagemaker\config.yaml

# %% [markdown]
# ### Initialize variables

# %%
aws_region='ca-central-1'
s3_bucket = 'tamperingdetection' + datetime.datetime.utcnow().strftime("%d-%m-%Y-%H%M%S")
model_s3_key = 'model.tar.gz'
framework='tensorflow'
version = '2.6'
initial_instance_count=1
instance_type='ml.m5.xlarge'
py_version='py38'
image_scope='inference'
models_dir = 'model'
models_artifact = '1'
path_to_archive_content = os.path.join(models_dir, models_artifact)
s3_client = boto3.client('s3')

# %% [markdown]
# ### Create S3 bucket

# %%
s3_client.create_bucket(
    Bucket=s3_bucket,
    CreateBucketConfiguration={
        'LocationConstraint': aws_region
    }
)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 s3_client.create_bucket(                                                                     │
# │   2 │   Bucket=s3_bucket,                                                                        │
# │   3 │   CreateBucketConfiguration={                                                              │
# │   4 │   │   'LocationConstraint': aws_region                                                     │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\client.py:570 in _api_call       │
# │                                                                                                  │
# │    567 │   │   │   │   │   f"{py_operation_name}() only accepts keyword arguments."              │
# │    568 │   │   │   │   )                                                                         │
# │    569 │   │   │   # The "self" in this scope is referring to the BaseClient.                    │
# │ ❱  570 │   │   │   return self._make_api_call(operation_name, kwargs)                            │
# │    571 │   │                                                                                     │
# │    572 │   │   _api_call.__name__ = str(py_operation_name)                                       │
# │    573                                                                                           │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\context.py:124 in wrapper        │
# │                                                                                                  │
# │   121 │   │   │   with start_as_current_context():                                               │
# │   122 │   │   │   │   if hook:                                                                   │
# │   123 │   │   │   │   │   hook()                                                                 │
# │ ❱ 124 │   │   │   │   return func(*args, **kwargs)                                               │
# │   125 │   │                                                                                      │
# │   126 │   │   return wrapper                                                                     │
# │   127                                                                                            │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\client.py:1013 in _make_api_call │
# │                                                                                                  │
# │   1010 │   │   │   │   self.meta.config, request_dict, operation_model                           │
# │   1011 │   │   │   )                                                                             │
# │   1012 │   │   │   apply_request_checksum(request_dict)                                          │
# │ ❱ 1013 │   │   │   http, parsed_response = self._make_request(                                   │
# │   1014 │   │   │   │   operation_model, request_dict, request_context                            │
# │   1015 │   │   │   )                                                                             │
# │   1016                                                                                           │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\client.py:1037 in _make_request  │
# │                                                                                                  │
# │   1034 │                                                                                         │
# │   1035 │   def _make_request(self, operation_model, request_dict, request_context):              │
# │   1036 │   │   try:                                                                              │
# │ ❱ 1037 │   │   │   return self._endpoint.make_request(operation_model, request_dict)             │
# │   1038 │   │   except Exception as e:                                                            │
# │   1039 │   │   │   self.meta.events.emit(                                                        │
# │   1040 │   │   │   │   f'after-call-error.{self._service_model.service_id.hyphenize()}.{operati  │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\endpoint.py:119 in make_request  │
# │                                                                                                  │
# │   116 │   │   │   operation_model,                                                               │
# │   117 │   │   │   request_dict,                                                                  │
# │   118 │   │   )                                                                                  │
# │ ❱ 119 │   │   return self._send_request(request_dict, operation_model)                           │
# │   120 │                                                                                          │
# │   121 │   def create_request(self, params, operation_model=None):                                │
# │   122 │   │   request = create_request_object(params)                                            │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\endpoint.py:196 in _send_request │
# │                                                                                                  │
# │   193 │   │   attempts = 1                                                                       │
# │   194 │   │   context = request_dict['context']                                                  │
# │   195 │   │   self._update_retries_context(context, attempts)                                    │
# │ ❱ 196 │   │   request = self.create_request(request_dict, operation_model)                       │
# │   197 │   │   success_response, exception = self._get_response(                                  │
# │   198 │   │   │   request, operation_model, context                                              │
# │   199 │   │   )                                                                                  │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\endpoint.py:132 in               │
# │ create_request                                                                                   │
# │                                                                                                  │
# │   129 │   │   │   )                                                                              │
# │   130 │   │   │   service_id = operation_model.service_model.service_id.hyphenize()              │
# │   131 │   │   │   event_name = f'request-created.{service_id}.{operation_model.name}'            │
# │ ❱ 132 │   │   │   self._event_emitter.emit(                                                      │
# │   133 │   │   │   │   event_name,                                                                │
# │   134 │   │   │   │   request=request,                                                           │
# │   135 │   │   │   │   operation_name=operation_model.name,                                       │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\hooks.py:412 in emit             │
# │                                                                                                  │
# │   409 │                                                                                          │
# │   410 │   def emit(self, event_name, **kwargs):                                                  │
# │   411 │   │   aliased_event_name = self._alias_event_name(event_name)                            │
# │ ❱ 412 │   │   return self._emitter.emit(aliased_event_name, **kwargs)                            │
# │   413 │                                                                                          │
# │   414 │   def emit_until_response(self, event_name, **kwargs):                                   │
# │   415 │   │   aliased_event_name = self._alias_event_name(event_name)                            │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\hooks.py:256 in emit             │
# │                                                                                                  │
# │   253 │   │   :return: List of (handler, response) tuples from all processed                     │
# │   254 │   │   │   │    handlers.                                                                 │
# │   255 │   │   """                                                                                │
# │ ❱ 256 │   │   return self._emit(event_name, kwargs)                                              │
# │   257 │                                                                                          │
# │   258 │   def emit_until_response(self, event_name, **kwargs):                                   │
# │   259 │   │   """                                                                                │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\hooks.py:239 in _emit            │
# │                                                                                                  │
# │   236 │   │   responses = []                                                                     │
# │   237 │   │   for handler in handlers_to_call:                                                   │
# │   238 │   │   │   logger.debug('Event %s: calling handler %s', event_name, handler)              │
# │ ❱ 239 │   │   │   response = handler(**kwargs)                                                   │
# │   240 │   │   │   responses.append((handler, response))                                          │
# │   241 │   │   │   if stop_on_response and response is not None:                                  │
# │   242 │   │   │   │   return responses                                                           │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\signers.py:106 in handler        │
# │                                                                                                  │
# │   103 │   │   # from a client's event emitter.  When a new request is created                    │
# │   104 │   │   # this method is invoked to sign the request.                                      │
# │   105 │   │   # Don't call this method directly.                                                 │
# │ ❱ 106 │   │   return self.sign(operation_name, request)                                          │
# │   107 │                                                                                          │
# │   108 │   def sign(                                                                              │
# │   109 │   │   self,                                                                              │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\signers.py:198 in sign           │
# │                                                                                                  │
# │   195 │   │   │   │   else:                                                                      │
# │   196 │   │   │   │   │   raise e                                                                │
# │   197 │   │   │                                                                                  │
# │ ❱ 198 │   │   │   auth.add_auth(request)                                                         │
# │   199 │                                                                                          │
# │   200 │   def _resolve_identity_cache(self, kwargs, cache, cache_key):                           │
# │   201 │   │   kwargs['identity_cache'] = cache                                                   │
# │                                                                                                  │
# │ c:\Users\HP\anaconda32\envs\iit_AIML\lib\site-packages\botocore\auth.py:424 in add_auth          │
# │                                                                                                  │
# │    421 │                                                                                         │
# │    422 │   def add_auth(self, request):                                                          │
# │    423 │   │   if self.credentials is None:                                                      │
# │ ❱  424 │   │   │   raise NoCredentialsError()                                                    │
# │    425 │   │   datetime_now = datetime.datetime.utcnow()                                         │
# │    426 │   │   request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)             │
# │    427 │   │   # This could be a retry.  Make sure the previous                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NoCredentialsError: Unable to locate credentials

# %% [markdown]
# ### Create model artifact archive

# %%
# !tar -czvf model.tar.gz model/1
# Out:
# model/1/
# model/1/keras_metadata.pb
# model/1/variables/
# model/1/variables/variables.data-00000-of-00001
# model/1/variables/variables.index
# model/1/saved_model.pb
# model/1/assets/

# %% [markdown]
# Create a tar.gz file from the model artifacts. We have saved the model artifacts as a directory named “1” containing serialized signatures and the state needed to run them, including variable values and vocabularies to deploy to Amazon SageMaker runtime. You can also include a custom inference file inference.py within the 'code' folder in the model artifact. The custom inference can be used for pre / post processing of the input image

# %% [markdown]
# ### Upload the model artifact to S3

# %%
def upload_file(file_name, bucket, object_name=None):

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = os.path.basename(file_name)

    # Upload the file
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

is_uploaded = upload_file(model_s3_key, s3_bucket, None)

# %% [markdown]
# ### Create the SageMaker Inference Endpoint

# %%
container = image_uris.retrieve(region=aws_region, 
                                framework=framework, 
                                version=version,
                                image_scope=image_scope,
                                py_version=py_version,
                                instance_type =instance_type)

model_url = f's3://{s3_bucket}/{model_s3_key}'

model = Model(image_uri=container, 
              model_data=model_url, 
              role=sagemaker_role)

endpoint_name = f"tamperingdetection-{datetime.datetime.utcnow():%Y-%m-%d-%H%M}"
print("EndpointName =", endpoint_name)

model.deploy(
    initial_instance_count=initial_instance_count,
    instance_type=instance_type,
    endpoint_name=endpoint_name
)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# EndpointName = tamperingdetection-2024-01-22-2126
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# ---!

# %% [markdown]
# ### Test the Inference endpoint

# %%
def convert_to_ela_image(path, quality):
    filename = path
    resaved_filename = 'tempresaved.jpg'
    im = Image.open(filename)
    bm = im.convert('RGB')
    im.close()
    im=bm
    im.save(resaved_filename, 'JPEG', quality = quality)
    resaved_im = Image.open(resaved_filename)
    ela_im = ImageChops.difference(im, resaved_im)
    extrema = ela_im.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1
    scale = 255.0 / max_diff
    ela_im = ImageEnhance.Brightness(ela_im).enhance(scale)
    im.close()
    bm.close()
    resaved_im.close()
    del filename
    del resaved_filename
    del im
    del bm
    del resaved_im
    del extrema
    del max_diff
    del scale
    return ela_im

# %%
sagemaker_runtime = boto3.client(
    "sagemaker-runtime", region_name=aws_region)

endpoint_name=endpoint_name

def check_image(image):
    
    X = []
    X.append(array(convert_to_ela_image(image, 90).resize((128, 128))).flatten() / 255.0)
    X = np.array(X)

    X = X.reshape(-1, 128, 128, 3)
    
    data = {'instances': X.tolist()}
    
    # Gets inference from the model hosted at the specified endpoint:
    response = sagemaker_runtime.invoke_endpoint(
        EndpointName=endpoint_name, 
        Body=json.dumps(data),
        ContentType="application/json"
        )

    # Decodes and prints the response body:
    #print(response['Body'].read().decode('utf-8'))
    predictions_res = json.loads(response['Body'].read().decode('utf-8'))
    predictions = predictions_res['predictions']
    
    print(predictions)
    
    pred_classes = np.argmax(predictions,axis = 1) 
    print(pred_classes)

# %%
check_image('images/predict/Paystub.jpg')
# Out:
# [[0.81719625, 0.182803765]]
# [0]

# %%
check_image('images/predict/TamperedPaystub.jpg')
# Out:
# [[0.120328978, 0.879671037]]
# [1]

# %% [markdown]
# ### Cleanup

# %%
# delete sagemaker inference endpoint
client = boto3.client('sagemaker')
client.delete_endpoint(
    EndpointName=endpoint_name
)
# Out:
# {'ResponseMetadata': {'RequestId': '67934615-9240-4642-b0cd-4d8207577550',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '67934615-9240-4642-b0cd-4d8207577550',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Mon, 22 Jan 2024 21:29:57 GMT'},
#   'RetryAttempts': 0}}

# %%
# empty s3 bucket and delete the bucket
s3_resource = boto3.resource('s3')
bucket = s3_resource.Bucket(s3_bucket)
bucket.objects.all().delete()
bucket.delete()
print("S3 bucket and contents deleted")
# Out:
# S3 bucket and contents deleted
